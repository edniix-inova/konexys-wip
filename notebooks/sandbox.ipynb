# %%
import os
     
current_dir = os.getcwd()       # shows current path
print (current_dir)

# %%
import os
import fastparquet
import pandas as pd 

home_path = '/home/edumaindev/repos/konexys-poc/'
data_path = os.path.join(home_path, 'data/hour-09/fcd-hour-09-part-001.parquet')
df = pd.read_parquet(data_path, engine="fastparquet")

print(df.head())
# Out:
#    timestep_time  vehicle_id  vehicle_speed   vehicle_type  vehicle_x  \
# 0        32400.0   29508_977      12.597719     passmedium   6.937015
# 1        32400.0   29567_496      17.376292  fordpasslarge   6.989365
# 2        32400.0   29567_564      14.584857     passmedium   6.961736
# 3        32400.0   29567_745      13.976516        cvsmall   6.961736
# 4        32400.0  29685_1048      17.029508      passlarge   6.956788
#
#    vehicle_y  vehicle_z
# 0  50.934015  56.500000
# 1  50.951808  50.000000
# 2  50.935952  52.502086
# 3  50.935952  52.502086
# 4  50.950733  53.000000

# %%
# Out:
# 3.0.0
# 23.0.0
